# %% [markdown]
# # Demographics Related to College Majors - Nathan Strong Jupyter Test
#
# ## What are the some of the demographics and social affects related to majors?
#
# ### Fields Being Tracked:
#
# __FOD1P - Recoded field of degree - first entry__<br>
# __FOD2P - Recoded field of degree - second entry__<br>
# __SEX - Sex__ (1 = male, 2=female)<br>
# __AGEP - Age__<br>
# __SCH - School enrollment:__<br>
# b    .N/A (less than 3 years old)
# <br>1    .No, has not attended in the last 3 months
# <br>2    .Yes, public school or public college
# <br>3    .Yes, private school or college or home school
# <br><br>
# __RAC1P - Recoded detailed race code__
# <br>1    .White alone
# <br>2    .Black or African American alone
# <br>3    .American Indian alone
# <br>4    .Alaska Native alone
# <br>5    .American Indian and Alaska Native tribes specified; or American Indian or Al
# NATIVITY - Nativity<br>
# __NOP - Nativity of parent__
# <br>1    .Native
# <br>2    .Foreign born

# %%
# %matplotlib inline
import pandas as pd
import os
import seaborn as sns

# %%
pums_dir='/Users/strong/Desktop/UCLA Data Science/module 0/Jupyter/csv_pus/'
pums_file='psam_pusa.csv'
df = pd.read_csv(os.path.join(pums_dir, pums_file))

# %%
df.head(5)
# Out:
#   RT       SERIALNO  DIVISION  SPORDER  PUMA  REGION  ST   ADJINC  PWGTP  \
# 0  P  2017000000016         6        1  2500       3   1  1011189    206
# 1  P  2017000000031         6        1  1800       3   1  1011189     45
# 2  P  2017000000061         6        1  2400       3   1  1011189    136
# 3  P  2017000000061         6        2  2400       3   1  1011189    121
# 4  P  2017000000061         6        3  2400       3   1  1011189    111
#
#    AGEP  ...  PWGTP71  PWGTP72  PWGTP73  PWGTP74  PWGTP75  PWGTP76  PWGTP77  \
# 0    73  ...       60       46      260      300      256      370      366
# 1    31  ...       55       31       11       19       43      103       14
# 2    41  ...      101       47      160      333      176       33      131
# 3    48  ...      147       49      213      197      108       38      150
# 4    16  ...       62       36      128      266      157       27      117
#
#    PWGTP78  PWGTP79  PWGTP80
# 0      293      250       62
# 1       49       49       98
# 2       74       30      185
# 3       53       43      114
# 4       54       22      149
#
# [5 rows x 286 columns]

# %%
df = df[['FOD1P', 'SEX', 'AGEP', 'SCH', 'RAC1P', 'NATIVITY']]

# %%
df.describe()
# Out:
#                FOD1P           SEX          AGEP           SCH         RAC1P  \
# count  400281.000000  1.638294e+06  1.638294e+06  1.589853e+06  1.638294e+06
# mean     4336.214504  1.510319e+00  4.142605e+01  1.287530e+00  2.042377e+00
# std      1717.513980  4.998937e-01  2.363143e+01  5.399610e-01  2.256501e+00
# min      1100.000000  1.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00
# 25%      2406.000000  1.000000e+00  2.100000e+01  1.000000e+00  1.000000e+00
# 50%      5007.000000  2.000000e+00  4.200000e+01  1.000000e+00  1.000000e+00
# 75%      6107.000000  2.000000e+00  6.000000e+01  1.000000e+00  2.000000e+00
# max      6403.000000  2.000000e+00  9.600000e+01  3.000000e+00  9.000000e+00
#
#            NATIVITY
# count  1.638294e+06
# mean   1.134128e+00
# std    3.407898e-01
# min    1.000000e+00
# 25%    1.000000e+00
# 50%    1.000000e+00
# 75%    1.000000e+00
# max    2.000000e+00

# %%
originalCountOfData = len(df)
print(f"original count of data: {originalCountOfData}")
# Out:
# original count of data: 1638294

# %%
print('Percentage of null values per-column:')
(df.isna().sum() / len(df)) * 100
# Out:
# Percentage of null values per-column:
# FOD1P       75.567206
# SEX          0.000000
# AGEP         0.000000
# SCH          2.956795
# RAC1P        0.000000
# NATIVITY     0.000000
# dtype: float64

# %%
# Remove rows with NaN rows
df = df.dropna()
newCountOfData = len(df)
print(f'Count of data without null values: {newCountOfData}')
print(f'Percecentage of data thrown out: {(originalCountOfData - newCountOfData) / originalCountOfData}')
# Out:
# Count of data without null values: 400281
# Percecentage of data thrown out: 0.75567205886123

# %% [markdown]
# ## Get data for college majors

# %%
majors_dir='/Users/strong/Desktop/UCLA Data Science/module 0/Jupyter'
majors_file='majors-list.csv'
dfMajors = pd.read_csv(os.path.join(majors_dir, majors_file))

# %%
# Convert all strings to numbers and remove the NaN rows
dfMajors['FOD1P'] = pd.to_numeric(dfMajors['FOD1P'], errors='coerce')
dfMajors.dropna()
# Out:
#       FOD1P                                  Major  \
# 0    1100.0                    GENERAL AGRICULTURE
# 1    1101.0  AGRICULTURE PRODUCTION AND MANAGEMENT
# 2    1102.0                 AGRICULTURAL ECONOMICS
# 3    1103.0                        ANIMAL SCIENCES
# 4    1104.0                           FOOD SCIENCE
# ..      ...                                    ...
# 169  5504.0                              GEOGRAPHY
# 170  5505.0                INTERNATIONAL RELATIONS
# 171  5506.0       POLITICAL SCIENCE AND GOVERNMENT
# 172  5507.0                              SOCIOLOGY
# 173  5599.0          MISCELLANEOUS SOCIAL SCIENCES
#
#                       Major_Category
# 0    Agriculture & Natural Resources
# 1    Agriculture & Natural Resources
# 2    Agriculture & Natural Resources
# 3    Agriculture & Natural Resources
# 4    Agriculture & Natural Resources
# ..                               ...
# 169                   Social Science
# 170                   Social Science
# 171                   Social Science
# 172                   Social Science
# 173                   Social Science
#
# [173 rows x 3 columns]

# %% [markdown]
# # Merge Data from Both Tables

# %%
dfFinal = pd.merge(df, dfMajors, how='inner', on='FOD1P')
dfFinal.head(1)
# Out:
#     FOD1P  SEX  AGEP  SCH  RAC1P  NATIVITY  \
# 0  6100.0    2    31  1.0      1         1
#
#                                  Major Major_Category
# 0  GENERAL MEDICAL AND HEALTH SERVICES         Health

# %%
# Change the Sex Column Cells from 1 & 2 to "Male" & "Female"
dfFinal['SEX'] = dfFinal['SEX'].map({1: 'Male', 2: 'Female'}).to_frame()
# Change the Nativity Column Cells from 1 & 2 to "Native" & "Foreign Born"
dfFinal['NATIVITY'] = dfFinal['NATIVITY'].map({1: 'Native', 2: 'Foreign born'}).to_frame()

# %% [markdown]
# # Okay, Lets Start with the Data Analysis Now..
# # The Question - What is the Relationship Between Demographics and Majors?
#
# ### Lets first see the distrobution of data.
# ### What is the Male to Female ratio in our data?

# %%
females_in_data_percentage = int(dfFinal['SEX'].value_counts(normalize=True)['Female'].round(2) * 100)
males_in_data_percentage =  int(dfFinal['SEX'].value_counts(normalize=True)['Male'].round(2) * 100)
print(f"Female: {females_in_data_percentage}% / {males_in_data_percentage}% : Male")
# Out:
# Female: 53% / 47% : Male

# %% [markdown]
# ### What are their ages?

# %%
print(dfFinal['AGEP'].describe().round(1))

mostCommonAge = dfFinal['AGEP'].value_counts().idxmax()
mostCommonAgeCount = dfFinal['AGEP'].value_counts().max()
mostCommonAgePercentage = (mostCommonAgeCount / dfFinal['AGEP'].count().sum()).round(3) * 100
print(f"Most common age is: {mostCommonAge} ({mostCommonAgeCount} people) at {mostCommonAgePercentage}% of the data.")
# Out:
# count    400281.0
# mean         50.0
# std          16.8
# min          19.0
# 25%          36.0
# 50%          49.0
# 75%          63.0
# max          96.0
# Name: AGEP, dtype: float64
# Most common age is: 34 (7942 people) at 2.0% of the data.

# %% [markdown]
# ## What are the most common majors?

# %%
mostCommonMajor = dfFinal['Major'].value_counts().idxmax()
mostCommonMajorCount = dfFinal['Major'].value_counts().max()
mostCommonMajorPercentage = (mostCommonMajorCount / dfFinal['Major'].count().sum()).round(2) * 100
uniqueMajorCount = dfFinal['Major'].nunique()

print(f"Most common major is: {mostCommonMajor} ({mostCommonMajorCount} people) at {mostCommonMajorPercentage}% of the data.")
print(f"There are {uniqueMajorCount} Majors in total.")
# Out:
# Most common major is: BUSINESS MANAGEMENT AND ADMINISTRATION (23919 people) at 6.0% of the data.
# There are 173 Majors in total.

# %%
hist = dfFinal['Major'].hist(bins=uniqueMajorCount, histtype='step')

# %% [markdown]
# ## Pivot data by Gender vs. Gender

# %%
dfMajorsByGender = dfFinal.groupby(['Major','SEX']).count()
dfMajorsByGenderPercent = dfMajorsByGender / dfFinal.groupby(['Major']).count()
dfMajorsByGenderPercent = dfMajorsByGenderPercent[['AGEP']]
dfMajorsByGenderPercent = dfMajorsByGenderPercent.rename(index=str, columns={"AGEP":"PercentOfTotal"})

# %%
dfMajorsByGenderPercent
# Out:
#                                          PercentOfTotal
# Major                            SEX
# ACCOUNTING                       Female        0.499296
#                                  Male          0.500704
# ACTUARIAL SCIENCE                Female        0.354331
#                                  Male          0.645669
# ADVERTISING AND PUBLIC RELATIONS Female        0.662482
# ...                                                 ...
# UNITED STATES HISTORY            Male          0.607759
# VISUAL AND PERFORMING ARTS       Female        0.773663
#                                  Male          0.226337
# ZOOLOGY                          Female        0.426279
#                                  Male          0.573721
#
# [345 rows x 1 columns]

# %%
dfFinalMerge = pd.merge(dfMajorsByGender, dfMajorsByGenderPercent, how='inner', on=('Major', 'SEX'))
dfFinalMerge = dfFinalMerge[['AGEP', 'PercentOfTotal']]
dfFinalMerge = dfFinalMerge.rename(index=str, columns={"AGEP":"Total"})

# %%
dfFinalMerge.sort_values('Total', ascending=False)
dfFinalMerge.sort_values(['Total','PercentOfTotal'], ascending=False)
dfFinalMerge.reset_index(inplace=True)
dfFinalMerge
# Out:
#                                 Major     SEX  Total  PercentOfTotal
# 0                          ACCOUNTING  Female   7092        0.499296
# 1                          ACCOUNTING    Male   7112        0.500704
# 2                   ACTUARIAL SCIENCE  Female     45        0.354331
# 3                   ACTUARIAL SCIENCE    Male     82        0.645669
# 4    ADVERTISING AND PUBLIC RELATIONS  Female    897        0.662482
# ..                                ...     ...    ...             ...
# 340             UNITED STATES HISTORY    Male    141        0.607759
# 341        VISUAL AND PERFORMING ARTS  Female    376        0.773663
# 342        VISUAL AND PERFORMING ARTS    Male    110        0.226337
# 343                           ZOOLOGY  Female    425        0.426279
# 344                           ZOOLOGY    Male    572        0.573721
#
# [345 rows x 4 columns]

# %%
dfFemale = dfFinalMerge[dfFinalMerge['SEX'] == "Female"]
dfFemale = dfFemale.sort_values(['PercentOfTotal'], ascending=False)
dfFemale.head(20)
# Out:
#                                                  Major     SEX  Total  \
# 94                           EARLY CHILDHOOD EDUCATION  Female   1571
# 124                       FAMILY AND CONSUMER SCIENCES  Female   3466
# 58       COMMUNICATION DISORDERS SCIENCES AND SERVICES  Female   1577
# 196                                    LIBRARY SCIENCE  Female    268
# 269                                            NURSING  Female  14811
# 220                         MEDICAL ASSISTING SERVICES  Female    482
# 110                               ELEMENTARY EDUCATION  Female  13420
# 325                            SPECIAL NEEDS EDUCATION  Female   1820
# 271                                 NUTRITION SCIENCES  Female    698
# 319                                        SOCIAL WORK  Female   3247
# 245           MISCELLANEOUS HEALTH MEDICAL PROFESSIONS  Female    772
# 26                           ART HISTORY AND CRITICISM  Female    862
# 192                       LANGUAGE AND DRAMA EDUCATION  Female   1695
# 170          HUMAN SERVICES AND COMMUNITY ORGANIZATION  Female    568
# 341                         VISUAL AND PERFORMING ARTS  Female    376
# 309                          SCHOOL STUDENT COUNSELING  Female    102
# 142                                  GENERAL EDUCATION  Female  11190
# 136  FRENCH GERMAN LATIN AND OTHER COMMON FOREIGN L...  Female   2148
# 102                             EDUCATIONAL PSYCHOLOGY  Female    161
# 160         HEALTH AND MEDICAL ADMINISTRATIVE SERVICES  Female   1024
#
#      PercentOfTotal
# 94         0.976990
# 124        0.928725
# 58         0.924385
# 196        0.914676
# 269        0.911502
# 220        0.909434
# 110        0.907922
# 325        0.878803
# 271        0.877987
# 319        0.856051
# 245        0.851158
# 26         0.831244
# 192        0.830069
# 170        0.791086
# 341        0.773663
# 309        0.772727
# 142        0.763510
# 136        0.762243
# 102        0.759434
# 160        0.755720

# %%
dfMale = dfFinalMerge[dfFinalMerge['SEX'] == "Male"]
dfMale = dfMale.sort_values(['PercentOfTotal'], ascending=False)
dfMale.head(20)
# Out:
#                                                  Major   SEX  Total  \
# 228                              MILITARY TECHNOLOGIES  Male     41
# 219        MECHANICAL ENGINEERING RELATED TECHNOLOGIES  Male    251
# 179                 INDUSTRIAL PRODUCTION TECHNOLOGIES  Male    633
# 7                                AEROSPACE ENGINEERING  Male    867
# 225                          METALLURGICAL ENGINEERING  Male    132
# 262          NAVAL ARCHITECTURE AND MARINE ENGINEERING  Male    169
# 109  ELECTRICAL, MECHANICAL, AND PRECISION TECHNOLO...  Male    118
# 217                             MECHANICAL ENGINEERING  Male   5901
# 81                               CONSTRUCTION SERVICES  Male    674
# 336           TRANSPORTATION SCIENCES AND TECHNOLOGIES  Male    999
# 230                     MINING AND MINERAL ENGINEERING  Male     89
# 115          ENGINEERING MECHANICS PHYSICS AND SCIENCE  Male    244
# 113              ENGINEERING AND INDUSTRIAL MANAGEMENT  Male    344
# 105                             ELECTRICAL ENGINEERING  Male   7374
# 280                              PETROLEUM ENGINEERING  Male     94
# 135                                           FORESTRY  Male    466
# 145                                GENERAL ENGINEERING  Male   3455
# 51                                   CIVIL ENGINEERING  Male   3128
# 117                           ENGINEERING TECHNOLOGIES  Male    234
# 107                  ELECTRICAL ENGINEERING TECHNOLOGY  Male    635
#
#      PercentOfTotal
# 228        1.000000
# 219        0.958015
# 179        0.921397
# 7          0.921360
# 225        0.904110
# 262        0.903743
# 109        0.900763
# 217        0.896536
# 81         0.886842
# 336        0.886424
# 230        0.881188
# 115        0.871429
# 113        0.870886
# 105        0.868449
# 280        0.854545
# 135        0.848816
# 145        0.846814
# 51         0.837483
# 117        0.826855
# 107        0.824675
